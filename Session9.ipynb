# %%
# %%writefile wordcount.py

from mrjob.job import MRJob

class WordCount(MRJob):
    
    def mapper(self, _, line):
        words = line.split(";")
        for word in words:
            yield (word, 1)
    
    def reducer(self, word, counts_iter):
        yield (word, sum(counts_iter))
    
if __name__ == '__main__':
    WordCount.run()
# Out:
# Overwriting wordcount.py

# %%
# %run wordcount.py wiki.csv
# Out:
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# No configs specified for inline runner
# Creating temp directory C:\Users\Petri\AppData\Local\Temp\wordcount.Petri.20191124.190437.488030
# Creating temp directory C:\Users\Petri\AppData\Local\Temp\wordcount.Petri.20191124.190437.488030
# Running step 1 of 1...
# Running step 1 of 1...
# job output is in C:\Users\Petri\AppData\Local\Temp\wordcount.Petri.20191124.190437.488030\output
# job output is in C:\Users\Petri\AppData\Local\Temp\wordcount.Petri.20191124.190437.488030\output
# Streaming final output from C:\Users\Petri\AppData\Local\Temp\wordcount.Petri.20191124.190437.488030\output...
# Streaming final output from C:\Users\Petri\AppData\Local\Temp\wordcount.Petri.20191124.190437.488030\output...
# "0"	2
# "0.0"	3
# "0.03601073716105185"	1
# "0.03968087125038916"	1
# "0.08654936342147872"	1
# "0.09161761707280763"	1
# "0.09316295036468333"	1
# "0.1824470558411366"	1
# "0.18285073413755"	1
# "0.18305803475960236"	1
# "0.360131679065518"	1
# "0.36298252646258217"	1
# "0.36783455776291374"	1
# "0.36827703469446316"	1
# "0.37208067316414134"	1
# "0.5450228197743124"	1
# "0.7355679464497317"	1
# "0.7428904278780685"	1
# "0.7729079540363373"	1
# "0.9423940561974513"	1
# "08:58:15"	1
# "08:58:17"	1
# "08:58:25"	1
# "08:58:34"	1
# "08:58:35"	1
# "08:58:41"	2
# "08:58:45"	2
# "08:58:47"	1
# "08:58:49"	3
# "08:58:50"	21
# "08:58:51"	11
# "1"	60
# "1.4885466951183588"	1
# "1.530372070259966"	1
# "1.5679130752480024"	1
# "1.7800838903985818"	1
# "1.9050722060701795"	1
# "10.248344197429757"	1
# "100.0"	3
# "11"	3
# "12"	2
# "13.592498329317117"	1
# "130032"	1
# "130034"	1
# "130035"	1
# "130036"	1
# "130039"	1
# "130046"	1
# "130047"	1
# "130049"	1
# "130050"	1
# "130052"	1
# "130076"	1
# "130080"	1
# "130083"	1
# "130086"	1
# "130087"	1
# "130093"	1
# "130097"	1
# "130100"	1
# "130103"	1
# "130107"	1
# "130153"	1
# "130154"	1
# "130155"	2
# "130157"	1
# "130159"	1
# "130160"	1
# "130162"	1
# "130163"	1
# "130164"	2
# "130166"	1
# "130167"	1
# "130169"	1
# "130171"	1
# "130173"	1
# "130206"	1
# "130210"	1
# "130213"	1
# "130214"	1
# "130224"	1
# "130225"	1
# "130227"	1
# "130228"	1
# "130275"	2
# "130278"	1
# "130279"	1
# "130280"	1
# "130281"	1
# "130286"	1
# "130287"	1
# "130288"	2
# "61.5127029"	1
# "61.5167198"	1
# "61.5170479"	1
# "61.5222435"	1
# "61.5265846"	1
# "61.5490913"	1
# "61.5508003"	1
# "61.5550041"	1
# "61.6734161"	1
# "61.6902733"	1
# "64.6399476188471"	1
# "65"	1
# "69.13432468568666"	1
# "7.496118316398335"	1
# "7.513017814409398"	1
# "7.722323289146276"	1
# "70"	1
# "71"	3
# "77"	1
# "78x"	1
# "8"	7
# "8.698570666778377"	1
# "80"	1
# "85"	2
# "9"	3
# "9.50208049538154"	1
# "90"	1
# "90039"	1
# "90040"	2
# "90042"	2
# "90707"	1
# "90709"	1
# "90710"	2
# "90711"	1
# "90925"	1
# "date"	1
# "direction"	1
# "latitude"	1
# "line"	1
# "longitude"	1
# "speed"	1
# "time"	1
# "vehicle"	1
# Removing temp directory C:\Users\Petri\AppData\Local\Temp\wordcount.Petri.20191124.190437.488030...
# Removing temp directory C:\Users\Petri\AppData\Local\Temp\wordcount.Petri.20191124.190437.488030...

# %%
# %%writefile wordcount2.py

from mrjob.job import MRJob

class WordCount(MRJob):
    def mapper(self, _, line):
        words = line.lower().split()
        for word in words:
            yield (word, 1)
            
    def combiner(self, word, counts_iter):
        yield (word, sum(counts_iter))
    
    def reducer(self, word, counts_iter):
        yield (word, sum(counts_iter))

if __name__ == '__main__':
    WordCount.run()
# Out:
# Overwriting wordcount2.py

# %%
# %run wordcount2.py wiki.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# No configs specified for inline runner
# No configs specified for inline runner
# Creating temp directory C:\Users\Petri\AppData\Local\Temp\wordcount2.Petri.20191124.190449.764985
# Creating temp directory C:\Users\Petri\AppData\Local\Temp\wordcount2.Petri.20191124.190449.764985
# Creating temp directory C:\Users\Petri\AppData\Local\Temp\wordcount2.Petri.20191124.190449.764985
# Running step 1 of 1...
# Running step 1 of 1...
# Running step 1 of 1...
# job output is in C:\Users\Petri\AppData\Local\Temp\wordcount2.Petri.20191124.190449.764985\output
# job output is in C:\Users\Petri\AppData\Local\Temp\wordcount2.Petri.20191124.190449.764985\output
# job output is in C:\Users\Petri\AppData\Local\Temp\wordcount2.Petri.20191124.190449.764985\output
# Streaming final output from C:\Users\Petri\AppData\Local\Temp\wordcount2.Petri.20191124.190449.764985\output...
# Streaming final output from C:\Users\Petri\AppData\Local\Temp\wordcount2.Petri.20191124.190449.764985\output...
# Streaming final output from C:\Users\Petri\AppData\Local\Temp\wordcount2.Petri.20191124.190449.764985\output...
# "1991,"	1
# "2018,"	1
# "30"	1
# "a"	4
# "after"	1
# "all"	1
# "an"	1
# "and"	8
# "are"	2
# "as"	2
# "automatic"	1
# "available"	1
# "both"	1
# "by"	2
# "clear"	1
# "code"	1
# "community"	1
# "community-based"	1
# "comprehensive"	1
# "constructs"	1
# "cpython"	1
# "cpython,"	1
# "created"	1
# "design"	1
# "development"	1
# "do"	1
# "down"	1
# "dynamic"	1
# "emphasizes"	1
# "enable"	1
# "features"	1
# "first"	1
# "for"	2
# "foundation."	1
# "functional"	1
# "general-purpose"	1
# "guido"	1
# "has"	3
# "high-level"	1
# "imperative,"	1
# "implementation"	1
# "implementations."	1
# "in"	3
# "including"	1
# "interpreted"	1
# "interpreters"	1
# "is"	2
# "it"	2
# "july"	1
# "language"	2
# "large"	2
# "leader"	1
# "library.[30]"	1
# "managed"	1
# "management."	1
# "many"	1
# "memory"	1
# "model,"	1
# "multiple"	1
# "nearly"	1
# "non-profit"	1
# "notably"	1
# "object-oriented,"	1
# "of"	2
# "on"	1
# "open"	1
# "operating"	1
# "other"	1
# "paradigms,"	1
# "philosophy"	1
# "procedural,"	1
# "programming"	3
# "programming."	1
# "provides"	1
# "python"	6
# "python's"	1
# "python,"	1
# "readability,"	1
# "reference"	1
# "released"	1
# "rossum"	2
# "scales.[27]"	1
# "significant"	1
# "small"	1
# "software"	1
# "software[31]"	1
# "source"	1
# "standard"	1
# "stepped"	1
# "supports"	1
# "system"	1
# "systems."	1
# "that"	2
# "the"	4
# "type"	1
# "using"	1
# "van"	2
# "whitespace."	1
# "years.[28][29]"	1
# Removing temp directory C:\Users\Petri\AppData\Local\Temp\wordcount2.Petri.20191124.190449.764985...
# Removing temp directory C:\Users\Petri\AppData\Local\Temp\wordcount2.Petri.20191124.190449.764985...
# Removing temp directory C:\Users\Petri\AppData\Local\Temp\wordcount2.Petri.20191124.190449.764985...

# %%
# %%writefile textstats.py

from mrjob.job import MRJob

class TextStats(MRJob):
    def mapper(self, _, line):
        import os
        file_name = os.getenv('mapreduce_map_input_file')
        wordCount = len(line.lower().split())
        charCount = len(line)
        lineCount = 1
        yield "w", wordCount
        yield "c", charCount
        yield "l", lineCount
        yield "fn", file_name
            
    def combiner(self, key, counts_iter):
        if key != "fn":
            yield key, sum(counts_iter)
        else:
            yield key, list(set(counts_iter))
    
    def reducer(self, key, counts_iter):
        if key == "w":
            yield "words", sum(counts_iter)
        elif key == "c":
            yield "chars", sum(counts_iter)
        elif key == "l":
            yield "lines", sum(counts_iter)
        else:
            yield "files", list(counts_iter)

if __name__ == '__main__':
    TextStats.run()
# Out:
# Overwriting textstats.py

# %%
# %run textstats.py wiki*.txt
# Out:
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# No configs specified for inline runner
# No configs specified for inline runner
# No configs specified for inline runner
# Creating temp directory C:\Users\Petri\AppData\Local\Temp\textstats.Petri.20191124.223724.873045
# Creating temp directory C:\Users\Petri\AppData\Local\Temp\textstats.Petri.20191124.223724.873045
# Creating temp directory C:\Users\Petri\AppData\Local\Temp\textstats.Petri.20191124.223724.873045
# Creating temp directory C:\Users\Petri\AppData\Local\Temp\textstats.Petri.20191124.223724.873045
# Running step 1 of 1...
# Running step 1 of 1...
# Running step 1 of 1...
# Running step 1 of 1...
# job output is in C:\Users\Petri\AppData\Local\Temp\textstats.Petri.20191124.223724.873045\output
# job output is in C:\Users\Petri\AppData\Local\Temp\textstats.Petri.20191124.223724.873045\output
# job output is in C:\Users\Petri\AppData\Local\Temp\textstats.Petri.20191124.223724.873045\output
# job output is in C:\Users\Petri\AppData\Local\Temp\textstats.Petri.20191124.223724.873045\output
# Streaming final output from C:\Users\Petri\AppData\Local\Temp\textstats.Petri.20191124.223724.873045\output...
# Streaming final output from C:\Users\Petri\AppData\Local\Temp\textstats.Petri.20191124.223724.873045\output...
# Streaming final output from C:\Users\Petri\AppData\Local\Temp\textstats.Petri.20191124.223724.873045\output...
# Streaming final output from C:\Users\Petri\AppData\Local\Temp\textstats.Petri.20191124.223724.873045\output...
# "chars"	3475
# "files"	[["file://wiki.txt"], ["file://wiki.txt"], ["file://wiki.txt"], ["file://wiki2.txt"], ["file://wiki2.txt"], ["file://wiki2.txt"]]
# "lines"	12
# "words"	491
# Removing temp directory C:\Users\Petri\AppData\Local\Temp\textstats.Petri.20191124.223724.873045...
# Removing temp directory C:\Users\Petri\AppData\Local\Temp\textstats.Petri.20191124.223724.873045...
# Removing temp directory C:\Users\Petri\AppData\Local\Temp\textstats.Petri.20191124.223724.873045...
# Removing temp directory C:\Users\Petri\AppData\Local\Temp\textstats.Petri.20191124.223724.873045...
